# %%
# !pip install google-generativeai python-dotenv
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Cambia el nombre del archivo PDF si es necesario
ruta_pdf = 'El Tribut - Fichas platos para Sala.pdf'

# %%
import pdfplumber
import os
import google.generativeai as genai
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv('GOOGLE_API_KEY')

# %%
genai.configure(api_key=api_key)

# %%
# Realizar una consulta simple
if 'api_key' in locals() and api_key:
    try:
        print("🤖 Haciendo consulta a Gemini (versión gratuita)...")
        
        # Crear el modelo (versión gratuita)
        model = genai.GenerativeModel('gemini-2.5-flash')
        
        # Hacer la consulta
        response = model.generate_content("Hola! Escribe un saludo amigable en español")
        
        respuesta = response.text
        print("✅ Respuesta recibida:")
        print("-" * 50)
        print(respuesta)
        print("-" * 50)
        
    except Exception as e:
        print(f"❌ Error en la consulta: {e}")
        print("💡 Si tienes error de cuota, asegúrate de usar la versión gratuita del modelo")
else:
    print("❌ Primero debes configurar la API Key en la celda anterior")
# Out:
# 🤖 Haciendo consulta a Gemini (versión gratuita)...
# ✅ Respuesta recibida:
# --------------------------------------------------
# ¡Claro! Aquí tienes algunas opciones amigables:
#
# 1.  **¡Hola! ¿Qué tal?** (Muy común y casual)
# 2.  **¡Hola a todos! Espero que estén muy bien.** (Si es para un grupo)
# 3.  **¡Saludos! Qué gusto saludarte.** (Un poco más formal pero muy cordial)
# 4.  **¡Hola! Es un placer conocerte/saludarte.** (Si es la primera vez)
#
# Elige el que más te guste. ¡Un saludo!
# --------------------------------------------------
# ✅ Respuesta recibida:
# --------------------------------------------------
# ¡Claro! Aquí tienes algunas opciones amigables:
#
# 1.  **¡Hola! ¿Qué tal?** (Muy común y casual)
# 2.  **¡Hola a todos! Espero que estén muy bien.** (Si es para un grupo)
# 3.  **¡Saludos! Qué gusto saludarte.** (Un poco más formal pero muy cordial)
# 4.  **¡Hola! Es un placer conocerte/saludarte.** (Si es la primera vez)
#
# Elige el que más te guste. ¡Un saludo!
# ...

# %%
texto_extraido = ''
with pdfplumber.open(ruta_pdf) as pdf:
    for pagina in pdf.pages:
        texto_extraido += pagina.extract_text() + '\n'

# Ahora el texto completo está en la variable texto_extraido

# %% [markdown]
# ## 4. Mostrar el texto extraído
# Visualiza el texto extraído para revisarlo o procesarlo.

# %%
# Muestra el texto extraído
print(texto_extraido)
# Out:
# Entrantes
# Entrantes
# ‘Montadito’ Matrimoni de seitó fresc amb crema
# d’anxova de l’Escala i salsa romesco (3 uds.)
# ES: Montadito Matrimonio de boquerón fresco con crema de anchoa de
# l’Escala y salsa romesco (3 uds.)
# ENG: Fresh anchovy marriage with l’Escala anchovy cream and romesco
# sauce in brioche (3 units)
# DESTACABLE:
# Lingote de pan brioche con crema de mascarpone, ricotta, anchoa y
# boquerón marinado con salsa romescada (salsa de tomate asado, ñora,
# almendras, ajo y vinagre de jerez)
# MARCADO:
# Recomendado para compartir y como aperitivo finger food.
# Es posible añadir una unidad si son 4 comensales.
# Marcar comensal con tenedor y cuchillo.
# Servir con pinzas.
# ALÉRGENOS: Gluten, frutos secos, lácteos, huevos, pescado, soja.
# Entrantes
# Bunyols de bacallà amb mussolina d’all
# negre (3 uds.)
# ES: Buñuelos de bacalao con muselina de ajo negro (3 uds.)
# ENG: Bunyols. Traditional cod fritters with black garlic mousseline (3 units)
# DESTACABLE:
# ...

# %%
import json

# Lista que contendrá todos los platos del menú (43 platos)
menu_data = [
    # --- ENTRANTES (17 PLATOS) ---
    {
      "nombre_plato": "Montadito Matrimoni de seitó fresc amb crema d'anxova de l'Escala i salsa romesco (3 uds.)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Boquerón fresco (seitó)", "Crema de anchoa (l'Escala)", "Salsa romesco (tomate, almendras)", "Pan brioche"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Romesco y Crema de Anchoa",
      "coccion": "Crudo / Marinado",
      "alergenos": [
        "Gluten", "Frutos secos", "Lácteos", "Huevos", "Pescado", "Soja"
      ]
    },
    {
      "nombre_plato": "Bunyols de bacallà amb mussolina d'all negre (3 uds.)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Bacalao", "Patata hervida", "Muselina de ajo negro", "Huevo", "Harina"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Muselina de Ajo Negro",
      "coccion": "Frito",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos", "Huevos", "Pescado", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Croquetes de pernil ibèric de gla amb el seu encenall (3 uds.)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Jamón ibérico de bellota", "Bechamel", "Cebolla", "Virutas de jamón"
      ],
      "carne": "Sí",
      "proteina_principal": "Cerdo Ibérico",
      "salsa": "Bechamel",
      "coccion": "Frito",
      "alergenos": [
        "Gluten", "Lácteos", "Mostaza", "Huevo", "Pescado"
      ]
    },
    {
      "nombre_plato": "Fritura de xipirons",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Chipirones (calamares pequeños)", "Harina (para rebozar)", "Lima"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Molusco",
      "salsa": "N/A",
      "coccion": "Frito",
      "alergenos": [
        "Gluten", "Crustáceos", "Huevos", "Pescado", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "La nostra brava de patata natural, fumada i cremada",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Patata natural (brava)", "Salsa brava", "Sabor ahumado"
      ],
      "carne": "No",
      "proteina_principal": "Vegetal/N/A",
      "salsa": "Salsa Brava",
      "coccion": "Frito / Ahumado",
      "alergenos": [
        "Mostaza", "Huevos"
      ]
    },
    {
      "nombre_plato": "Tonyina vermella ikejime soasada amb tocs acevichats, rovell curat i salsa ponzu",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Atún rojo (tonyina vermella) ikejime", "Yema curada", "Salsa ponzu", "Jengibre", "Cilantro"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Ponzu",
      "coccion": "Soasado / Crudo",
      "alergenos": [
        "Gluten", "Soja", "Apio", "Sulfitos", "Pescado", "Crustáceos"
      ]
    },
    {
      "nombre_plato": "Ceviche de gambot vermell amb alvocat i pipes de carbassa",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Gambón rojo (gamba roja)", "Leche de tigre (limón, ají)", "Aguacate (alvocat)", "Pipas de calabaza"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Crustáceo",
      "salsa": "Leche de Tigre (Cítrica)",
      "coccion": "Crudo / Marinado",
      "alergenos": [
        "Crustáceos", "Mostaza", "Pescado", "Soja", "Gluten", "Apio"
      ]
    },
    {
      "nombre_plato": "Musclos Bouchot al vapor",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Mejillones Bouchot", "Vino blanco", "Eneldo", "Ajo", "Limón"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Molusco",
      "salsa": "N/A",
      "coccion": "Vapor",
      "alergenos": [
        "Moluscos", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Cloïsses a la planxa amb oli verd, all i julivert",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Almejas (cloïsses) de Galicia", "Aceite verde", "Ajo (all)", "Perejil (julivert)", "Vino blanco"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Molusco",
      "salsa": "Aceite y Vino Blanco",
      "coccion": "Plancha",
      "alergenos": [
        "Moluscos", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Navalles a la graella amb chimichurri d'algues",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Navajas (navalles) de Galicia", "Chimichurri de algas", "Zumo de limón", "Orégano"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Molusco",
      "salsa": "Chimichurri de Algas",
      "coccion": "Parrilla / Brasa",
      "alergenos": [
        "Gluten", "Cereales", "Moluscos"
      ]
    },
    {
      "nombre_plato": "Pernil ibèric de gla tallat a mà (50g / 100g)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Jamón ibérico 100% de bellota 'Señorío de Montanera'"
      ],
      "carne": "Sí",
      "proteina_principal": "Cerdo Ibérico",
      "salsa": "N/A",
      "coccion": "Curado / Crudo",
      "alergenos": [
        "N/A"
      ]
    },
    {
      "nombre_plato": "Cecina de Black Angus amb ametlles laminades i reducció de vedella (50g / 100g)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Cecina de Black Angus", "Almendras laminadas", "Reducción de ternera"
      ],
      "carne": "Sí",
      "proteina_principal": "Ternera",
      "salsa": "Demi-Glace / Reducción",
      "coccion": "Curado / Crudo",
      "alergenos": [
        "Gluten", "Cereales", "Lácteo", "Frutos secos"
      ]
    },
    {
      "nombre_plato": "Varietats de tomàquets amb sardina fumada i porro escalivat, ceba encurtida, mató, fulles d'alfàbrega i oli verd",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Variedades de tomates", "Sardina ahumada", "Puerro asado", "Mató (queso fresco)", "Vinagreta"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Vinagreta",
      "coccion": "Ahumado",
      "alergenos": [
        "Pescado", "Lácteos"
      ]
    },
    {
      "nombre_plato": "Llamàntol farcit 'd'Ensaladilla' d'El Tribut amb maionesa cítrica i ous de salmó sobre gel sec (unitats limitades)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Bogavante cocido", "Carne de bogavante", "Ensaladilla", "Mayonesa cítrica", "Huevas de salmón"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Crustáceo",
      "salsa": "Mayonesa Cítrica",
      "coccion": "Cocido / Frío",
      "alergenos": [
        "Pescado", "Marisco", "Lácteos", "Huevos", "Soja", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Burrata de la Puglia amb moniato al forn, mel calenta, ratlladura de llima, ametlles torrades i escates de sal",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Burrata de Bufala", "Boniato (moniato) asado", "Miel caliente", "Ralladura de lima", "Almendras tostadas"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Miel caliente (Reducción)",
      "coccion": "Asado",
      "alergenos": [
        "Frutos secos", "Lácteos", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Pa de vidre amb tomàquet (4 llesques)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Pan de coca de cristal", "Tomate (tomàquet)"
      ],
      "carne": "No",
      "proteina_principal": "Vegetal/N/A",
      "salsa": "N/A",
      "coccion": "Tostado",
      "alergenos": [
        "Gluten"
      ]
    },
    {
      "nombre_plato": "Pa de massa mare amb mantega fumada d'herbes mediterrànies (2 uds.)",
      "categoria": "Entrante",
      "ingredientes_clave": [
        "Pan de masa madre", "Mantequilla ahumada de hierbas mediterráneas"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Mantequilla Aromática",
      "coccion": "Braseado",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos"
      ]
    },
    # --- PRINCIPALES (13 PLATOS) ---
    {
      "nombre_plato": "Macarrons 'a la Barceloneta' amb vaca madurada i secret ibèric",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Macarrones", "Sofrito Cardinale", "Vaca madurada", "Secreto ibérico", "Bechamel", "Demi-glace"
      ],
      "carne": "Sí",
      "proteina_principal": "Mixta (Ternera y Cerdo)",
      "salsa": "Bechamel y Demi-Glace",
      "coccion": "Horneado / Gratinado",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos", "Huevos", "Soja", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Canelons de carn de rostit picada a mà amb beixamel suau (3 uds.)",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Canelones", "Pollo", "Morcillo de ternera", "Paté de foie", "Bechamel suave", "Demi-glace"
      ],
      "carne": "Sí",
      "proteina_principal": "Mixta (Ave, Ternera y Foie)",
      "salsa": "Bechamel y Demi-Glace",
      "coccion": "Asado / Gratinado",
      "alergenos": [
        "Gluten", "Lácteos", "Huevos", "Soja", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Tagliatto Onglet ' Tall de vedella macerada al grill amb patates fregides (240g)",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Ternera Onglet (entraña)", "Demi-glace", "Romero", "Patatas fritas"
      ],
      "carne": "Sí",
      "proteina_principal": "Ternera",
      "salsa": "Demi-Glace",
      "coccion": "Parrilla / Grill",
      "alergenos": [
        "Gluten"
      ]
    },
    {
      "nombre_plato": "Cors de carxofa confitats amb 'gremolata' de fruits secs i cremós de mongetes de Santa Pau",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Corazones de alcachofa confitada", "Gremolata de frutos secos", "Cremoso de alubias de Santa Pau"
      ],
      "carne": "No",
      "proteina_principal": "Vegetal/N/A",
      "salsa": "Cremoso de Alubias",
      "coccion": "Confitado",
      "alergenos": [
        "Lácteos", "Frutos secos", "Gluten", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Entrecot de vedella lleugerament madurat amb patates pont neuf al forn i mantega (350g)",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Entrecot (ribeye) madurado", "Hierbas mediterráneas (tomillo, romero)", "Mantequilla de hierbas", "Patatas Pont Neuf"
      ],
      "carne": "Sí",
      "proteina_principal": "Ternera",
      "salsa": "Mantequilla de Hierbas",
      "coccion": "Plancha / Horno",
      "alergenos": [
        "Gluten", "Lácteos"
      ]
    },
    {
      "nombre_plato": "Filet Wellington d'El Tribut amb foie, duxelle de bolets i la nostra demi glace",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Solomillo de ternera (filet)", "Hojaldre", "Duxelle de setas", "Foie gras", "Demi-glace"
      ],
      "carne": "Sí",
      "proteina_principal": "Ternera",
      "salsa": "Demi-Glace",
      "coccion": "Horneado",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos", "Huevos", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Corball a la brasa amb cremós de carbassa i tomàquets Diví",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Suprema de corvina", "Cremoso de calabaza", "Tomates cherry confitados", "Pipas de calabaza"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Cremoso de Calabaza",
      "coccion": "Braseado / Parrilla",
      "alergenos": [
        "Crustáceos", "Lácteos", "Moluscos", "Cacahuetes", "Mostaza", "Pescado", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Morro de bacallà amb dàtils, fruits secs i parmentier trufada amb bolets confitats",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Lomo de bacalao", "Parmentier trufada", "Dátiles", "Setas confitadas", "Pasas en ratafía"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Parmentier",
      "coccion": "Confitado / Baja Temperatura",
      "alergenos": [
        "Frutos secos", "Lácteos", "Pescado", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Pasta fresca de nero de sèpia farcida de rap, lluç i marisc amb salsa de crustacis i formatge Grana Padano",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Pasta de tinta de calamar", "Relleno (vieira, gamba, merluza)", "Salsa americana (txangurro)", "Queso Grana Padano"
      ],
      "carne": "No",
      "proteina_principal": "Pescado y Marisco",
      "salsa": "Americana de Crustáceos",
      "coccion": "Cocido / Gratinado",
      "alergenos": [
        "Gluten", "Cereales", "Crustáceos", "Huevos", "Lácteos", "Moluscos", "Pescado", "Sulfitos"
      ]
    },
    {
      "nombre_plato": "Calamar d'El Tribut farcit de magre amb botifarra negra, carbassó i reducció dels seus sucs",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Calamar", "Relleno (magra de cerdo, botifarra negra)", "Sepia en su tinta", "Reducción de jugos (ratafía)"
      ],
      "carne": "Sí",
      "proteina_principal": "Mar y Tierra (Cerdo)",
      "salsa": "Reducción de Jugos / Tinta de Sepia",
      "coccion": "Plancha / Relleno",
      "alergenos": [
        "Gluten", "Crustáceos", "Huevos", "Pescado", "Soja"
      ]
    },
    {
      "nombre_plato": "Llobarro a la Meunière al tall de papallona amb cols de brussel·les i tàperes liofilitzades",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Lubina (Llobarro) braseada", "Salsa Meunière (mantequilla, limón)", "Coles de Bruselas", "Alcaparras liofilizadas"
      ],
      "carne": "No",
      "proteina_principal": "Pescado",
      "salsa": "Meunière",
      "coccion": "Braseado / Horno",
      "alergenos": [
        "Crustáceos", "Moluscos", "Pescado", "Lácteos"
      ]
    },
    {
      "nombre_plato": "Arròs d'El Tribut de botifarres esparracades amb perol gratinat i allioli d'ametlles",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Arroz", "Botifarras (negra y blanca)", "Caldo de rustido", "Sofrito", "Perol gratinado", "Allioli de almendras"
      ],
      "carne": "Sí",
      "proteina_principal": "Cerdo",
      "salsa": "Allioli de Almendras",
      "coccion": "Seco / Sofrito",
      "alergenos": [
        "Cereales", "Frutos secos", "Huevos", "Lácteos", "Soja"
      ]
    },
    {
      "nombre_plato": "Arròs d'hortalisses amb carxofes confitades, espàrrecs verds i gírgoles",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Arroz", "Caldo de verduras asadas", "Sofrito", "Alcachofas confitadas", "Espárragos verdes", "Setas Maitake"
      ],
      "carne": "No",
      "proteina_principal": "Vegetal/N/A",
      "salsa": "N/A",
      "coccion": "Seco / Sofrito",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos", "Huevos"
      ]
    },
    {
      "nombre_plato": "Arròs amb gamba vermella, musclos i calamar amb fumet de marisc, peix de roca i cigala",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Arroz", "Gamba roja", "Mejillón Bouchot", "Calamar", "Fumet de marisco y roca", "Sofrito de sepia (24h)"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Pescado",
      "salsa": "N/A",
      "coccion": "Seco / Sofrito",
      "alergenos": [
        "Gluten", "Cereales", "Frutos secos", "Crustáceos", "Moluscos", "Pescado"
      ]
    },
    {
      "nombre_plato": "Cassola d'arròs caldós de llamàntol amb fumet de marisc",
      "categoria": "Principal",
      "ingredientes_clave": [
        "Arroz", "Bogavante (Llamàntol)", "Fumet de marisco y pescado", "Sofrito de sepia (24h)", "Pescado del mercado"
      ],
      "carne": "No",
      "proteina_principal": "Marisco/Pescado",
      "salsa": "N/A",
      "coccion": "Caldoso / Guisado",
      "alergenos": [
        "Gluten", "Cereales", "Frutos secos", "Crustáceos", "Moluscos", "Pescado", "Sulfitos"
      ]
    },
    # --- POSTRES (12 PLATOS) ---
    {
      "nombre_plato": "Cremós de mató del Cadí amb mel de romaní i el seu cruixent amb nous pacanes",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Requesón (mató) del Cadí (mousse)", "Miel de romero", "Nueces pecanas caramelizadas", "Crujiente"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Miel de Romero",
      "coccion": "Frío / Emulsionado",
      "alergenos": [
        "Frutos secos", "Lácteos", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Sorbete de fruita de temporada",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Sorbete de fruta de temporada (ej. Limón, lima)", "Crumble de galleta"
      ],
      "carne": "No",
      "proteina_principal": "Vegetal/N/A",
      "salsa": "N/A",
      "coccion": "Frío / Helado",
      "alergenos": [
        "Lácteos"
      ]
    },
    {
      "nombre_plato": "Maduixes macerades amb suc de taronja natural i escuma de mascarpone",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Fresas (maduixes) del Maresme", "Zumo de naranja/pomelo/lima", "Espuma sifón de mascarpone", "Crema inglesa"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/Fruta",
      "salsa": "Crema Inglesa / Mascarpone",
      "coccion": "Frío / Macerado",
      "alergenos": [
        "Lácteos", "Huevos"
      ]
    },
    {
      "nombre_plato": "Pa de pessic de festucs",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Bizcocho (pa de pessic) casero", "Pistacho (festucs)", "Almíbar de romero"
      ],
      "carne": "No",
      "proteina_principal": "N/A",
      "salsa": "Almíbar de Romero",
      "coccion": "Horneado",
      "alergenos": [
        "Gluten", "Frutos secos", "Huevo"
      ]
    },
    {
      "nombre_plato": "Tatin de milfulles de poma amb crema anglesa i gelat de vainilla",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Milhojas (hojaldre)", "Carpaccio de manzana asada", "Cremoso de manzana (canela)", "Crema inglesa", "Helado de vainilla"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/Fruta",
      "salsa": "Crema Inglesa",
      "coccion": "Horneado / Asado",
      "alergenos": [
        "Gluten", "Cereales", "Lácteos", "Huevos", "Soja", "Cacahuetes", "Frutos secos"
      ]
    },
    {
      "nombre_plato": "Flam de 'dulce de leche' i cruixent de neules",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Flan tradicional", "Dulce de leche", "Nata", "Crujiente de neula (barquillo)", "Chocolate blanco"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Dulce de Leche",
      "coccion": "Cocido / Caramelizado",
      "alergenos": [
        "Gluten", "Huevos", "Lácteos", "Cacahuetes", "Soja", "Frutos secos"
      ]
    },
    {
      "nombre_plato": "Braç de gitano de nata Chantilly",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Plancha de bizcocho caramelizada", "Relleno de nata fresca", "Nata chantilly de vainilla"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Nata Chantilly",
      "coccion": "Horneado",
      "alergenos": [
        "Gluten", "Frutos secos", "Cereales", "Lácteos", "Huevos", "Soja", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Lingot de tres xocolates amb ganache de xocolata",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Chocolate (tres texturas)", "Mousse de chocolate", "Ganache de chocolate"
      ],
      "carne": "No",
      "proteina_principal": "N/A",
      "salsa": "Ganache de Chocolate",
      "coccion": "Frío / Mousse",
      "alergenos": [
        "Gluten", "Frutos secos", "Cereales", "Lácteos", "Huevos", "Soja", "Cacahuetes"
      ]
    },
    {
      "nombre_plato": "Torrada de Santa Teresa 'Torrija' amb crème brûlée i gelat de ratafia",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Pan de brioche (torrija)", "Crème brûlée (crema catalana)", "Helado casero de ratafía", "Crumble de galleta"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "Crème Brûlée",
      "coccion": "Horneado / Caramelizado",
      "alergenos": [
        "Gluten", "Frutos secos", "Cereales", "Lácteos", "Huevos", "Dióxido azufre"
      ]
    },
    {
      "nombre_plato": "Crema catalana amb cardamom, anís estrellat i crumble",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Crema de leche (infusionada)", "Cardamomo", "Anís estrellado", "Ralladura de limón y lima", "Crumble de galleta"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "N/A",
      "coccion": "Caramelizado",
      "alergenos": [
        "Gluten", "Frutos secos", "Cereales", "Lácteos", "Huevos"
      ]
    },
    {
      "nombre_plato": "Gelat del Tribut d'avellanes, xocolata, farigola i aigua de mar",
      "categoria": "Postre",
      "ingredientes_clave": [
        "Helado mantecoso de avellanas", "Chocolate", "Agua de mar", "Tomillo (farigola)", "Crumble de galleta"
      ],
      "carne": "No",
      "proteina_principal": "Lácteo/N/A",
      "salsa": "N/A",
      "coccion": "Frío / Helado",
      "alergenos": [
        "Frutos secos", "Lácteos", "Soja"
      ]
    }
]

# Imprimir la lista de diccionarios como una única cadena JSON (formato legible)
json_output = json.dumps(menu_data, indent=4, ensure_ascii=False)
print("--- JSON COMPLETO IMPRESO EN CONSOLA ---")
print(json_output)
# Out:
# --- JSON COMPLETO IMPRESO EN CONSOLA ---
# [
#     {
#         "nombre_plato": "Montadito Matrimoni de seitó fresc amb crema d'anxova de l'Escala i salsa romesco (3 uds.)",
#         "categoria": "Entrante",
#         "ingredientes_clave": [
#             "Boquerón fresco (seitó)",
#             "Crema de anchoa (l'Escala)",
#             "Salsa romesco (tomate, almendras)",
#             "Pan brioche"
#         ],
#         "carne": "No",
#         "proteina_principal": "Pescado",
#         "salsa": "Romesco y Crema de Anchoa",
#         "coccion": "Crudo / Marinado",
#         "alergenos": [
#             "Gluten",
#             "Frutos secos",
#             "Lácteos",
#             "Huevos",
#             "Pescado",
#             "Soja"
#         ]
#     },
#     {
#         "nombre_plato": "Bunyols de bacallà amb mussolina d'all negre (3 uds.)",
#         "categoria": "Entrante",
#         "ingredientes_clave": [
#             "Bacalao",
#             "Patata hervida",
# ...

# %% [markdown]
# 1. Transformación del Dataset de Platos (Feature Engineering)
# La lista menu_data está en formato Python. La convierto en un DataFrame de Pandas para que sea fácil de analizar y fusionar.

# %%
import pandas as pd
import json

# [Tu lista menu_data completa, tal como la definiste en el prompt, iría aquí]

# Crear un DataFrame de Pandas a partir de la lista de diccionarios
df_platos = pd.DataFrame(menu_data)

# Realizar One-Hot Encoding en las variables categóricas clave (variables ficticias)
# Esto es crucial para que el modelo pueda "leer" las características del plato.
features_to_encode = ['categoria', 'proteina_principal', 'salsa', 'coccion']
df_platos_encoded = pd.get_dummies(df_platos, columns=features_to_encode, drop_first=True)

# Opcional: Expandir alergenos e ingredientes (para análisis avanzado)
# df_platos_encoded['alergenos_count'] = df_platos_encoded['alergenos'].apply(len)

# Mostrar las primeras filas con las nuevas variables
print("--- DATAFRAME DE PLATOS LISTO PARA ML ---")
print(df_platos_encoded[['nombre_plato', 'carne'] + [col for col in df_platos_encoded.columns if 'proteina_principal' in col]].head())
# Out:
# --- DATAFRAME DE PLATOS LISTO PARA ML ---
#                                         nombre_plato carne  \
# 0  Montadito Matrimoni de seitó fresc amb crema d...    No
# 1  Bunyols de bacallà amb mussolina d'all negre (...    No
# 2  Croquetes de pernil ibèric de gla amb el seu e...    Sí
# 3                                Fritura de xipirons    No
# 4  La nostra brava de patata natural, fumada i cr...    No
#
#    proteina_principal_Cerdo Ibérico  proteina_principal_Lácteo/Fruta  \
# 0                             False                            False
# 1                             False                            False
# 2                              True                            False
# 3                             False                            False
# 4                             False                            False
#
#    proteina_principal_Lácteo/N/A  proteina_principal_Mar y Tierra (Cerdo)  \
# ...

# %%
# ===== Recomendador simple de vinos  =====
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

wines = [
    {"id": 1, "nombre": "Albariño Rías Baixas", "descripcion": "Aroma a fruta blanca, acidez fresca, notas cítricas y florales"},
    {"id": 2, "nombre": "Garnacha Rosada", "descripcion": "Frutos rojos, ligero cuerpo, buena acidez, notas herbáceas"},
    {"id": 3, "nombre": "Cava Brut Reserva", "descripcion": "Burbujas finas, notas de panadería, acidez refrescante, combinable con mariscos"},
    {"id": 4, "nombre": "Rioja Crianza Tinto", "descripcion": "Firme estructura, notas de vainilla y tostado, fruta roja madura"},
    {"id": 5, "nombre": "Priorat Garnacha/Carignan", "descripcion": "Cuerpo pleno, taninos marcados, fruta negra, intensa mineralidad"},
    {"id": 6, "nombre": "Chardonnay barrica", "descripcion": "Cuerpo medio-alto, notas de mantequilla, vainilla y fruta tropical"},
    {"id": 7, "nombre": "Moscatel dulce", "descripcion": "Aromático, notas florales y de miel, perfecto para postres"},
    {"id": 8, "nombre": "Jerez Fino", "descripcion": "Seco, notas salinas y frutos secos, excelente con mariscos y fritos"},
]
df_wines = pd.DataFrame(wines)

# Prepara texto combinado para vinos (nombre + descripcion)
df_wines['text'] = df_wines['nombre'] + ' ' + df_wines['descripcion']

# Prepara texto representativo para cada plato: nombre + ingredientes clave (join)
def plato_text(row):
    # ingredientes_clave puede ser lista; si no existe, usar vacío
    ingreds = row.get('ingredientes_clave', []) if isinstance(row, dict) else (row['alergenos'] if 'alergenos' in row else [])
    # si la columna es lista en DataFrame, ya está bien
    if isinstance(ingreds, list):
        ingreds_str = ' '.join([str(x) for x in ingreds])
    else:
        ingreds_str = str(ingreds)
    return str(row['nombre_plato']) + ' ' + ingreds_str

# Construir corpus para TF-IDF: todos los platos + todos los vinos
platos_corpus = df_platos['nombre_plato'].astype(str) + ' ' + df_platos['ingredientes_clave'].astype(str).str.replace('
',' ')
wines_corpus = df_wines['text']
corpus = pd.concat([platos_corpus.reset_index(drop=True), wines_corpus.reset_index(drop=True)], ignore_index=True)

# Vectorizar con TF-IDF (usar ngramas y eliminar stopwords en español/inglés)
vectorizer = TfidfVectorizer(ngram_range=(1,2), stop_words='spanish')
X = vectorizer.fit_transform(corpus)

# Separar las matrices
X_platos = X[:len(platos_corpus)]
X_wines = X[len(platos_corpus):]

# Función de recomendación: dado índice de plato, devuelve top-k vinos
def recommend_wines_for_plato(plato_idx, top_k=3):
    # calc similitud entre plato y todos los vinos
    sim = cosine_similarity(X_platos[plato_idx], X_wines).flatten()
    top_idx = np.argsort(sim)[::-1][:top_k]
,
    return results.reset_index(drop=True)

print('Recomendador cargado. Usa recommend_wines_for_plato(idx_plato) para obtener recomendaciones.')
# Out:
#   Cell In[12], line 35
#     platos_corpus = df_platos['nombre_plato'].astype(str) + ' ' + df_platos['ingredientes_clave'].astype(str).str.replace('
#                                                                                                                           ^
# SyntaxError: unterminated string literal (detected at line 35)
